# %% [markdown]
# <a href="https://colab.research.google.com/github/abram056/AI-ML-Fundamentals/blob/main/notebooks/Module_4_EDA_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 4 – Exploratory Data Analysis (EDA)
# ## Objectives
# - Understand datasets
# - Summarize data
# - Visualize patterns
# - Detect missing values
# - Investigate relationships

# %% [markdown]
# ## 1. Loading the Dataset

# %%
# for colab runtime
# !wget https://raw.githubusercontent.com/abram056/AI-ML-Fundamentals/refs/heads/main/datasets/tested.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("tested(1).csv")
df.head()

# %% [markdown]
# ### Do It Yourself
# Load the dataset and display the first 10 rows.

# %%
# Your code here

# %% [markdown]
# ## 2. Understanding the Dataset

# %%
df.info()
df.shape
df.columns

# %% [markdown]
# ## 3. Descriptive Statistics

# %%
df.describe(include='all')

# %% [markdown]
# ## 4. Exploring Features

# %%
df["Age"].head()
df["Sex"].value_counts()
df["Pclass"].value_counts()

# %% [markdown]
# ## 5. Visualizations

# %%
df["Age"].hist(bins=20)
plt.show()
df["Sex"].value_counts().plot(kind='bar')
plt.show()
plt.boxplot(df["Fare"].dropna())
plt.show()

# %% [markdown]
# ## 6. Comparing Categories

# %%
df.groupby("Sex")["Survived"].mean()
df.groupby("Pclass")["Survived"].mean()

# %% [markdown]
# ## 7. Relationships

# %%
plt.scatter(df["Age"],df["Fare"])
plt.show()
df.select_dtypes(include='number').corr()

# %% [markdown]
# ## 8. Missing Values

# %%
df.isnull().sum()
(df.isnull().sum()/len(df))*100

# %% [markdown]
# ## 9. Mini Lab
# Investigate the Titanic dataset and answer the questions from the module.

# %%
# Your solution here

# %% [markdown]
# ## Homework Challenge
# Create a report with charts, observations, features for prediction, and one data quality issue.
