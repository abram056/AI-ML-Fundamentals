# %% [markdown]
# <a href="https://colab.research.google.com/github/abram056/AI-ML-Fundamentals/blob/main/notebooks/module_3_notebook_completed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome

# %% [markdown]
# ## Python for AI
#
# Welcome!
#
# Throughout this notebook you'll write code, answer questions, and complete small challenges.
#
# Don't worry about making mistakes.
#
# Experimenting is part of learning.

# %% [markdown]
# # Variables

# %%
name = "Alice"
age = 22
height = 1.68
is_student = True

print(name)
print(age)
print(height)
print(is_student)

# %% [markdown]
# ### Do It Yourself
# Create variables named
# - city
# - favorite_food
# - temperature
#
# Print them.

# %%
# Solution

# %% [markdown]
# # Lists

# %%
scores = [75, 82, 91, 68]

print(scores)
print(scores[0])
print(scores[-1])

# %% [markdown]
# ### Do It Yourself
# Create a list containing five of your favourite movies.
#
# Print
# - first movie
# - last movie

# %% [markdown]
# # Dictionaries

# %%
student = {
    "name":"Alice",
    "age":20,
    "course":"AI"
}

student

# %%
# access values through their keys
student["name"]

# %% [markdown]
# ### Do It Yourself
# Create a dictionary describing yourself.
#
# Include:
# - name
# - age
# - height
# - favorite_color

# %%
# Solution

# %% [markdown]
# # Loops

# %% [markdown]
# ## For loop

# %%
scores = [55,60,72,91]

for score in scores:
    print(score)

# %% [markdown]
# ### Do It Yourself
# Create a loop that prints the square of each number in `scores`.

# %%
# Your code here

# %% [markdown]
# # Functions
# Functions let us reuse code.

# %%
def average(numbers):
    return sum(numbers)/len(numbers)

print(average([75,82,91,68]))

# %% [markdown]
# ### Do It Yourself
# Write a function called `maximum` that returns the largest value in a list.

# %%
# Your code here

# %% [markdown]
# # NumPy
# NumPy provides fast numerical arrays.

# %%
import numpy as np

arr = np.array([1,2,3,4,5])
print(arr*2)
print(arr.mean())

# %% [markdown]
# ### Do It Yourself
# Create a NumPy array containing five ages and compute the average.

# %%
# Your code here

# %% [markdown]
# # Pandas
# Pandas is used to work with tabular data. To experiment, we'll be using the a sample dataset, the Titanic dataset.

# %%
# !wget https://raw.githubusercontent.com/abram056/AI-ML-Fundamentals/refs/heads/main/datasets/tested.csv

# %%
import pandas as pd

df = pd.read_csv('tested.csv')
df.head()

# %%
df.info()

# %%
df.describe(include='all')

# %% [markdown]
# ### Do It Yourself
# - Display the first 10 rows.
# - List all column names.
# - Select the `Age` column.
# - Count missing values.

# %%
# Your code here

# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as plt

df['Age'].hist()
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
df['Sex'].value_counts().plot(kind='bar')
plt.title('Passengers by Sex')
plt.show()

# %% [markdown]
# ### Do It Yourself
# Create a histogram for the `Fare` column and a bar chart for the `Embarked` column.

# %%
# Your code here

# %% [markdown]
# # Mini Lab: Exploring the Titanic Dataset
# Complete the following tasks using everything you've learned.

# %% [markdown]
# 1. Load the dataset.
# 2. Display the first five rows.
# 3. Find the number of rows and columns.
# 4. List the column names.
# 5. Find the average age.
# 6. Count missing values.
# 7. Find the survival rate.
# 8. Create a histogram of passenger ages.
# 9. Create a bar chart showing survival counts.
# 10. Write three observations about the dataset.

# %%
# Write your solution here
